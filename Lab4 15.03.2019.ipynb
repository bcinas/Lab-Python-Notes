# %%
def main():
    readFile()
    
    
def writeFile():
    outfile = open('Names.txt', 'w')
    
    for x in range(7):
        name = input("Enter a city name: ")
        outfile.write(name + '\n')
        
    outfile.close()
    
def readFile():
    infile = open('Names.txt', 'r')
    line = infile.readline()
    
    while line != '':
        print(line.rstrip())
        line = infile.readLine()
    
    infile.close()
    
def appendFile():
    outfile = open('Names.txt', 'a')
    num = int(input('How many names would you like to add?'))
    
    for x in range(''):
        outfile.write(input('Enter a city name: ') + '\n')
            
    outfile.close()
    
main()
# Out:
# Elazıg
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-da66bf94d8e6> in <module>
#      31     outfile.close()
#      32
# ---> 33 main()
#
# <ipython-input-17-da66bf94d8e6> in main()
#       1 def main():
# ----> 2     readFile()
#       3
#       4
#       5 def writeFile():
#
# <ipython-input-17-da66bf94d8e6> in readFile()
#      18     while line != '':
#      19         print(line.rstrip())
# ---> 20         line = infile.readLine()
#      21
#      22     infile.close()
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'readLine'

# %%
def main():
    print('----------------')
    
    readFile()
    
    
def writeFile():
    outfile = open('Names.txt', 'w')
    
    for x in range(7):
        name = input("Enter a city name: ")
        outfile.write(name + '\n')
        
    outfile.close()
    
def readFile():
    infile = open('Names.txt', 'r')
    line = infile.readline()
    
    while line != '':
        print(line.rstrip())
        line = infile.readLine()
    
    infile.close()
    
def appendFile():
    outfile = open('Names.txt', 'a')
    num = int(input('How many names would you like to add?'))
    
    for x in range(''):
        outfile.write(input('Enter a city name: ') + '\n')
            
    outfile.close()
    
main()

# %%
def main():
    select = 0
    while select != 5:
        print('---------------------------')
        print('To create a new file, press 1.')
        print('To append data to your file, press 2.')
        print('To display file data, press 3.')
        print('To search for a name, press 4.')
        print('To exist, press 5.')
        print('---------------------------')

        try:
            select = int(input('Enter your choice: '))

            if select == 1:
                writeFile()
            elif select == 2:
                appendFile()
            elif select == 3:
                readFile()
            elif select == 4:
                findName()
            elif select == 5:
                message()
            else:
                print('Retry!')

        except ValueError as err:
            print(err)

def findName():
    try:
        infile = open('Names.txt','r')
        name = input('Enter the name you are looking for ')
        found = False
        line = infile.readline()

        while line != '':
            if name == line.rstrip():
                found = True
            line = infile.readline()
        if found:
            print(name, 'is available in the file.')
        else:
            print(name, 'is not available in the file.')

    except Exception as err:
        print(err)

def message():
    print('You have request to quit.')
    print('--------> END <----------')

def writeFile():
    outfile = open('Names.txt', 'w')

    for x in range(7):
        name = input('Enter a city name: ')
        outfile.write(name + '\n')

    outfile.close()

def readFile():
    infile = open('Names.txt', 'r')
    line = infile.readline()

    while line != '':
        print(line.rstrip())
        line = infile.readline()

    infile.close()

def appendFile():
    outfile = open('Names.txt', 'a')
    num = int(input('How many names would you like to add? '))

    for x in range(num):
        outfile.write(input('Enter a city name: ')+'\n')

    outfile.close()
main()
# Out:
# ---------------------------
# To create a new file, press 1.
# To append data to your file, press 2.
# To display file data, press 3.
# To search for a name, press 4.
# To exist, press 5.
# ---------------------------
# Enter your choice: 1
# Enter a city name: a
# Enter a city name: b
# Enter a city name: c
# Enter a city name: d
# Enter a city name: e
# Enter a city name: f
# Enter a city name: g
# ---------------------------
# To create a new file, press 1.
# To append data to your file, press 2.
# To display file data, press 3.
# To search for a name, press 4.
# To exist, press 5.
# ---------------------------
# Enter your choice: 4
# Enter the name you are looking for a
# a is available in the file.
# ---------------------------
# To create a new file, press 1.
# To append data to your file, press 2.
# To display file data, press 3.
# To search for a name, press 4.
# To exist, press 5.
# ---------------------------
